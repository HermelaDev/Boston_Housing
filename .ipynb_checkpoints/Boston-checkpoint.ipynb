# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
boston = pd.read_csv("BostonHousing.csv")

# %%
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
### Exploring the Shape
boston.shape
# Out:
# (506, 14)

# %%
boston.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## Cleaning Data

# %%
#checking for null values
boston.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
# checking for duplicates
boston.duplicated().sum()
# Out:
# 0

# %%
# Renaming columns
boston.columns = ["crime_Rate",
    "zoned_Land",
    "industrial_Acres",
    "river_Proximity",
    "nitric_Oxides",
    "rooms_per_dwelling",
    "age_of_home",
    "employment_Distance",
    "highway_Accessibility",
    "property_Tax_Rate",
    "pupil_teacher_ratio",
    "black_Residents_Rate",
    "lower_Status_Population",
    "median_Home_Value"]

boston.tail(7)
# Out:
#      crime_Rate  zoned_Land  industrial_Acres  river_Proximity  nitric_Oxides  \
# 499     0.17783         0.0              9.69                0          0.585
# 500     0.22438         0.0              9.69                0          0.585
# 501     0.06263         0.0             11.93                0          0.573
# 502     0.04527         0.0             11.93                0          0.573
# 503     0.06076         0.0             11.93                0          0.573
# 504     0.10959         0.0             11.93                0          0.573
# 505     0.04741         0.0             11.93                0          0.573
#
#      rooms_per_dwelling  age_of_home  employment_Distance  \
# 499               5.569         73.5               2.3999
# 500               6.027         79.7               2.4982
# 501               6.593         69.1               2.4786
# 502               6.120         76.7               2.2875
# ...

# %%
# Removing the columns that we won't need for this time 
boston = boston[["crime_Rate",
    "river_Proximity",
    "nitric_Oxides",
    "rooms_per_dwelling",
    "age_of_home",
    "employment_Distance",
    "highway_Accessibility",
    "property_Tax_Rate",
    "black_Residents_Rate"]]

boston.head(7)
# Out:
#    crime_Rate  river_Proximity  nitric_Oxides  rooms_per_dwelling  \
# 0     0.00632                0          0.538               6.575
# 1     0.02731                0          0.469               6.421
# 2     0.02729                0          0.469               7.185
# 3     0.03237                0          0.458               6.998
# 4     0.06905                0          0.458               7.147
# 5     0.02985                0          0.458               6.430
# 6     0.08829                0          0.524               6.012
#
#    age_of_home  employment_Distance  highway_Accessibility  property_Tax_Rate  \
# 0         65.2               4.0900                      1                296
# 1         78.9               4.9671                      2                242
# 2         61.1               4.9671                      2                242
# 3         45.8               6.0622                      3                222
# ...

# %%
boston.dtypes
# Out:
# crime_Rate               float64
# river_Proximity            int64
# nitric_Oxides            float64
# rooms_per_dwelling       float64
# age_of_home              float64
# employment_Distance      float64
# highway_Accessibility      int64
# property_Tax_Rate          int64
# black_Residents_Rate     float64
# dtype: object

# %% [markdown]
# ### Features Understanding

# %%
tax = boston['property_Tax_Rate'].value_counts().head(10).plot(kind='bar', title='Tax Rates Count')

tax.set_xlabel('Property Tax Rate')
tax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
NO = boston['nitric_Oxides'].plot(kind='kde', title='Nitric Oxides Distribution')

NO.set_xlabel('nitric_Oxides')
# Out:
# Text(0.5, 0, 'nitric_Oxides')

# %% [markdown]
# ### Features Relationships

# %%
boston.plot(kind = 'scatter', x='rooms_per_dwelling', y='property_Tax_Rate')
# Out:
# <Axes: xlabel='rooms_per_dwelling', ylabel='property_Tax_Rate'>

# %%
boston.plot(kind = 'scatter', x='black_Residents_Rate', y='crime_Rate')
# Out:
# <Axes: xlabel='black_Residents_Rate', ylabel='crime_Rate'>

# %%
sns.pairplot(boston, vars=["crime_Rate",
    "river_Proximity",
    "nitric_Oxides",
    "rooms_per_dwelling",
    "age_of_home",
    "employment_Distance",
    "highway_Accessibility",
    "property_Tax_Rate",
    "black_Residents_Rate"])
plt.show()

# %%
boston_corr = boston[["crime_Rate",
    "river_Proximity",
    "nitric_Oxides",
    "rooms_per_dwelling",
    "age_of_home",
    "employment_Distance",
    "highway_Accessibility",
    "property_Tax_Rate",
    "black_Residents_Rate"]].corr()

boston_corr
# Out:
#                        crime_Rate  river_Proximity  nitric_Oxides  \
# crime_Rate               1.000000        -0.055892       0.420972
# river_Proximity         -0.055892         1.000000       0.091203
# nitric_Oxides            0.420972         0.091203       1.000000
# rooms_per_dwelling      -0.219247         0.091251      -0.302188
# age_of_home              0.352734         0.086518       0.731470
# employment_Distance     -0.379670        -0.099176      -0.769230
# highway_Accessibility    0.625505        -0.007368       0.611441
# property_Tax_Rate        0.582764        -0.035587       0.668023
# black_Residents_Rate    -0.385064         0.048788      -0.380051
#
#                        rooms_per_dwelling  age_of_home  employment_Distance  \
# crime_Rate                      -0.219247     0.352734            -0.379670
# river_Proximity                  0.091251     0.086518            -0.099176
# nitric_Oxides                   -0.302188     0.731470            -0.769230
# ...

# %%
sns.heatmap(boston_corr)
# Out:
# <Axes: >
